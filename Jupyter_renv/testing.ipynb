# %%
library(ggplot2)
library(ggpubr)

library(here)

.libPaths()

plot(c(1:10),c(21:30), type="b",xlab="x",ylab="y")

# %% [markdown]
# # notes
#
# this is used to test how to use renv and jupyter together.
# there is a subfolder also use renv and it show how.
#
# There still one issue: renv doesn't keep tract of .ipynb for libraries. We could add library to the ./DESCRIPTION file or use a separate .R file to keep track of this?
#
# To do renv routines, we could do
#
#     R -e "renv::install('here')"
#     R -e "renv::status()"
#     R -e "renv::snapshot()" # this will generate a renv.lock file

# %% [markdown]
# About sub structure/folder, we have reference
#
# https://stackoverflow.com/questions/71242328/renv-venv-jupyterlab-irkernel-will-it-blend

# %%
renv::status()

# %%
renv::repair()
