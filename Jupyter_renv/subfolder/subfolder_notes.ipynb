# %%
#this is the one used to test the renv with subfolders
library(ggplot2)
library(ggpubr)
library(MASS)
library(dplyr)
library(tidyr)
library(rstatix)
.libPaths()
x<-seq(0, 100, 10)
y<-5*x^2+10
plot(x,y, type="b", xlab="x", ylab="quadratic")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:MASS’:
#
#     select
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
# [1] "/home/feng/Feng/hg/Jupyter_renv/renv/library/R-4.3/x86_64-conda-linux-gnu"
# [2] "/home/feng/.cache/R/renv/sandbox/R-4.3/x86_64-conda-linux-gnu/aab5eb63"
# plot without title

# %% [markdown]
# # note about renv using jupyter.
# ref: https://github.com/rstudio/renv/issues/946
#
#
#         I think you might need to either change the working directory before sourcing the renv/activate.R script, or explicitly call renv::load("/path/to/project/root").
#
#         This seems to work:
#
#         # Try the fix
#         echo 'owd <- setwd(".."); source("renv/activate.R"); setwd(owd)' > .Rprofile
#         R -e "fortunes::fortune()"  # works, but bootstraps a new renv
#         R -e "fortunes::fortune()"  # does not work the second time
#
#         In theory, the renv activate script could also try to figure out the project root directory automatically as well to support the case you suggest above.
#
#
#
# This solves the issue to have a subfolder in jupyter project, but it does not by need to set up the .Rprofile for every folder!!! ( this is different from running R script in the different subfolders. because for R script, I start R consolde always at the root folder (project folder). But in here, the jupyter has to start the R kernel as the very first thing. The way we force it is to do it with .Rprofile at every subfolder. We still could set up after the jupyter starts, but at that time we already has done with setting up library path, etc. we could only use "here" to do working directory, etc.
# This is very different.
# !!!

# %%
dat<-data.frame(x=x, y=y)
ggplot(data=dat, aes(x,y))+
    geom_point()+
    geom_line()
# Out:
# plot without title
